# %%
 import numpy as np
 import pandas as pd

 import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
chirps_15s    = np.array(
    [44.000,46.400,43.600,35.000,35.000,32.600,28.900,27.700,25.500,20.375,\
     12.500,37.000,37.500,36.500,36.200,33.000,43.000,46.000,29.000,31.700,\
     31.000,28.750,23.500,32.400,31.000,29.500,22.500,20.600,35.000,33.100,\
     31.500,28.800,21.300,37.800,37.000,37.100,36.200,31.400,30.200,31.300,\
     26.100,25.200,23.660,22.250,17.500,15.500,14.750,15.000,14.000,18.500,\
     27.700,26.000,21.700,12.500,12.500],  dtype=float)

temp_celsius = np.array(
    [26.944, 25.833, 25.556, 23.056, 21.389, 20.000, 18.889, 18.333, 16.389,\
     13.889, 12.778, 24.583, 23.333, 23.333, 22.500, 18.889, 25.278, 25.833,\
     20.278, 20.278, 20.000, 18.889, 15.000, 21.111, 20.556, 19.444, 16.250,\
     14.722, 22.222, 21.667, 20.556, 19.167, 15.556, 23.889, 22.917, 22.500,\
     21.111, 19.722, 18.889, 20.556, 17.222, 17.222, 16.111, 16.667, 13.611,\
     12.778, 11.111, 11.667, 10.000, 11.111, 18.333, 17.222, 15.000, 10.417,\
     9.5833],  dtype=float)

for i, c in enumerate(chirps_15s):
  print("{} chirps in 15 sec in {} degree celcius".format(c, temp_celsius[i]))
# Out:
# 44.0 chirps in 15 sec in 26.944 degree celcius
# 46.4 chirps in 15 sec in 25.833 degree celcius
# 43.6 chirps in 15 sec in 25.556 degree celcius
# 35.0 chirps in 15 sec in 23.056 degree celcius
# 35.0 chirps in 15 sec in 21.389 degree celcius
# 32.6 chirps in 15 sec in 20.0 degree celcius
# 28.9 chirps in 15 sec in 18.889 degree celcius
# 27.7 chirps in 15 sec in 18.333 degree celcius
# 25.5 chirps in 15 sec in 16.389 degree celcius
# 20.375 chirps in 15 sec in 13.889 degree celcius
# 12.5 chirps in 15 sec in 12.778 degree celcius
# 37.0 chirps in 15 sec in 24.583 degree celcius
# 37.5 chirps in 15 sec in 23.333 degree celcius
# 36.5 chirps in 15 sec in 23.333 degree celcius
# 36.2 chirps in 15 sec in 22.5 degree celcius
# 33.0 chirps in 15 sec in 18.889 degree celcius
# 43.0 chirps in 15 sec in 25.278 degree celcius
# 46.0 chirps in 15 sec in 25.833 degree celcius
# 29.0 chirps in 15 sec in 20.278 degree celcius
# 31.7 chirps in 15 sec in 20.278 degree celcius
# ...

# %%
import matplotlib.pyplot as plt
X = chirps_15s
y = temp_celsius
plt.scatter(X, y, color = 'magenta')
plt.show()

# %%
model1 = tf.keras.Sequential([  
   tf.keras.layers.Dense(units = 1, input_shape = [1])                           
])

model1.compile(
    loss = 'mean_squared_error',
    optimizer = tf.keras.optimizers.Adam(0.1)
)

history1 = model1.fit(X, y, epochs = 500, verbose = 2)
# Out:
# Epoch 1/500
# 2/2 - 0s - loss: 163.7371
# Epoch 2/500
# 2/2 - 0s - loss: 47.4891
# Epoch 3/500
# 2/2 - 0s - loss: 5.0857
# Epoch 4/500
# 2/2 - 0s - loss: 14.4763
# Epoch 5/500
# 2/2 - 0s - loss: 34.3203
# Epoch 6/500
# 2/2 - 0s - loss: 37.0719
# Epoch 7/500
# 2/2 - 0s - loss: 24.5312
# Epoch 8/500
# 2/2 - 0s - loss: 9.7842
# Epoch 9/500
# 2/2 - 0s - loss: 3.0886
# Epoch 10/500
# 2/2 - 0s - loss: 5.4344
# Epoch 11/500
# 2/2 - 0s - loss: 10.8010
# Epoch 12/500
# 2/2 - 0s - loss: 12.3961
# Epoch 13/500
# 2/2 - 0s - loss: 9.4095
# Epoch 14/500
# 2/2 - 0s - loss: 5.3411
# Epoch 15/500
# 2/2 - 0s - loss: 2.8430
# Epoch 16/500
# 2/2 - 0s - loss: 3.4001
# Epoch 17/500
# 2/2 - 0s - loss: 5.1162
# Epoch 18/500
# 2/2 - 0s - loss: 5.5427
# Epoch 19/500
# 2/2 - 0s - loss: 4.5151
# Epoch 20/500
# 2/2 - 0s - loss: 3.1530
# Epoch 21/500
# 2/2 - 0s - loss: 2.5687
# Epoch 22/500
# 2/2 - 0s - loss: 2.9123
# Epoch 23/500
# 2/2 - 0s - loss: 3.5006
# Epoch 24/500
# 2/2 - 0s - loss: 3.4324
# Epoch 25/500
# ...

# %%
model1.predict([34])
# Out:
# array([[21.281359]], dtype=float32)

# %%
model2 = tf.keras.Sequential([  
   tf.keras.layers.Dense(units = 4, input_shape = [1])                           
])

model2.compile(
    loss = 'mean_squared_error',
    optimizer = tf.keras.optimizers.Adam(0.1)
)

history2 = model2.fit(X, y, epochs = 999, verbose = True)
# Out:
# Epoch 1/999
# 2/2 [==============================] - 0s 4ms/step - loss: 237.0051
# Epoch 2/999
# 2/2 [==============================] - 0s 2ms/step - loss: 101.1899
# Epoch 3/999
# 2/2 [==============================] - 0s 3ms/step - loss: 36.4983
# Epoch 4/999
# 2/2 [==============================] - 0s 2ms/step - loss: 12.7698
# Epoch 5/999
# 2/2 [==============================] - 0s 2ms/step - loss: 13.0011
# Epoch 6/999
# 2/2 [==============================] - 0s 2ms/step - loss: 23.3490
# Epoch 7/999
# 2/2 [==============================] - 0s 2ms/step - loss: 31.3591
# Epoch 8/999
# 2/2 [==============================] - 0s 2ms/step - loss: 30.9935
# Epoch 9/999
# 2/2 [==============================] - 0s 2ms/step - loss: 24.2682
# Epoch 10/999
# 2/2 [==============================] - 0s 2ms/step - loss: 15.5539
# Epoch 11/999
# 2/2 [==============================] - 0s 2ms/step - loss: 9.3365
# Epoch 12/999
# 2/2 [==============================] - 0s 3ms/step - loss: 4.8222
# ...

# %%
model3 = tf.keras.Sequential([  
   tf.keras.layers.Dense(units = 4, input_shape = [1]),
   tf.keras.layers.Dense(units = 2, input_shape = [4])                           
])

model3.compile(
    loss = 'mean_squared_error',
    optimizer = tf.keras.optimizers.Adam(0.1)
)

history3 = model3.fit(X, y, epochs = 322, verbose = True)
# Out:
# Epoch 1/322
# 2/2 [==============================] - 0s 1ms/step - loss: 660.9332
# Epoch 2/322
# 2/2 [==============================] - 0s 3ms/step - loss: 138.2012
# Epoch 3/322
# 2/2 [==============================] - 0s 2ms/step - loss: 24.3129
# Epoch 4/322
# 2/2 [==============================] - 0s 2ms/step - loss: 28.5846
# Epoch 5/322
# 2/2 [==============================] - 0s 2ms/step - loss: 34.0137
# Epoch 6/322
# 2/2 [==============================] - 0s 3ms/step - loss: 32.1345
# Epoch 7/322
# 2/2 [==============================] - 0s 2ms/step - loss: 8.8111
# Epoch 8/322
# 2/2 [==============================] - 0s 2ms/step - loss: 15.7436
# Epoch 9/322
# 2/2 [==============================] - 0s 2ms/step - loss: 27.8750
# Epoch 10/322
# 2/2 [==============================] - 0s 3ms/step - loss: 11.4571
# Epoch 11/322
# 2/2 [==============================] - 0s 2ms/step - loss: 6.1308
# Epoch 12/322
# 2/2 [==============================] - 0s 2ms/step - loss: 10.8304
# ...
